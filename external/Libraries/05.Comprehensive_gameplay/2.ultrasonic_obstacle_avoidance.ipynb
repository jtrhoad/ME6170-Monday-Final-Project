# %% [raw]
# @Copyright (C): 2015-2024, Shenzhen Yahboom Tech
# @Author: clhchan
# @Date: 2024-07-23 10:10:02

# %%
#!/usr/bin/python3
# -*- coding: UTF-8 -*-
import sys
sys.path.append('/home/pi/project_demo/lib')
#导入麦克纳姆小车驱动库 Import Mecanum Car Driver Library
from McLumk_Wheel_Sports import *

# Constants related to the ultrasonic sensor
NEAR_DISTANCE = 200  # Define near distance threshold (millimeters)
FAR_DISTANCE = 425   # Define far distance threshold (millimeters)

def car_avoid():


    # 读取超声波传感器的距离 Reading distance from ultrasonic sensor
    diss_H =bot.read_data_array(0x1b,1)[0]
    diss_L =bot.read_data_array(0x1a,1)[0]
    dis = diss_H << 8 | diss_L 

    # 打印距离 Printing distance
    #print(f"Ultrasonic Distance: {dis} mm")
    time.sleep(0.05)  # 每隔1秒读取一次距离 Read the distance every 1 second

    if dis < NEAR_DISTANCE:
        print(f"Obstacle is very close, distance: {dis} mm")
        move_backward(speed)
        time.sleep(0.1)
    elif NEAR_DISTANCE <= dis <= FAR_DISTANCE:
        print(f"Obstacle is at medium distance, distance: {dis} mm")
        stop_robot()
        time.sleep(0.2)
        rotate_left(speed)
        time.sleep(0.15)
    elif FAR_DISTANCE < dis:
        print(f"No obstacle, distance: {dis} mm")
        move_forward(speed)

    else:
        print("Unknown situation, stopping")
        stop_robot()
        time.sleep(0.2)

speed = 20  # Set vehicle speed

try:
    # 打开超声波测距功能 Turn on the ultrasonic ranging function
    bot.Ctrl_Ulatist_Switch(1)
    time.sleep(0.1)  # 给超声波传感器一点时间来测量 Give the ultrasonic sensor some time to measure
    while True:
        car_avoid()

except KeyboardInterrupt:
    # When the user interrupts the program, ensure all motors stop
    bot.Ctrl_Ulatist_Switch(0)
    time.sleep(0.1)
    stop_robot()
    print("Ending")
# Out:
# Obstacle is at medium distance, distance: 391 mm
# Obstacle is at medium distance, distance: 391 mm
# Obstacle is at medium distance, distance: 357 mm
# Obstacle is at medium distance, distance: 374 mm
# Obstacle is at medium distance, distance: 357 mm
# Obstacle is at medium distance, distance: 374 mm
# No obstacle, distance: 578 mm
# No obstacle, distance: 952 mm
# No obstacle, distance: 952 mm
# No obstacle, distance: 561 mm
# No obstacle, distance: 918 mm
# No obstacle, distance: 918 mm
# No obstacle, distance: 901 mm
# No obstacle, distance: 884 mm
# No obstacle, distance: 884 mm
# No obstacle, distance: 867 mm
# No obstacle, distance: 850 mm
# No obstacle, distance: 833 mm
# No obstacle, distance: 816 mm
# No obstacle, distance: 799 mm
# No obstacle, distance: 782 mm
# No obstacle, distance: 561 mm
# No obstacle, distance: 748 mm
# No obstacle, distance: 731 mm
# No obstacle, distance: 714 mm
# No obstacle, distance: 697 mm
# No obstacle, distance: 680 mm
# No obstacle, distance: 629 mm
# No obstacle, distance: 527 mm
# No obstacle, distance: 510 mm
# No obstacle, distance: 561 mm
# Obstacle is at medium distance, distance: 357 mm
# Obstacle is very close, distance: 85 mm
# Obstacle is very close, distance: 85 mm
# No obstacle, distance: 918 mm
# Obstacle is very close, distance: 153 mm
# Obstacle is very close, distance: 153 mm
# Obstacle is very close, distance: 153 mm
# No obstacle, distance: 1054 mm
# Obstacle is very close, distance: 153 mm
# No obstacle, distance: 1088 mm
# No obstacle, distance: 1105 mm
# No obstacle, distance: 1241 mm
# No obstacle, distance: 1122 mm
# No obstacle, distance: 1037 mm
# Obstacle is very close, distance: 153 mm
# No obstacle, distance: 969 mm
# No obstacle, distance: 1802 mm
# No obstacle, distance: 1071 mm
# No obstacle, distance: 1054 mm
# No obstacle, distance: 1054 mm
# No obstacle, distance: 1088 mm
# Obstacle is very close, distance: 102 mm
# Obstacle is very close, distance: 34 mm
# Obstacle is very close, distance: 51 mm
# Obstacle is very close, distance: 119 mm
# Obstacle is very close, distance: 153 mm
# Obstacle is very close, distance: 170 mm
# No obstacle, distance: 901 mm
# No obstacle, distance: 1122 mm
# No obstacle, distance: 1241 mm
# Obstacle is at medium distance, distance: 289 mm
# Obstacle is at medium distance, distance: 204 mm
# Obstacle is at medium distance, distance: 204 mm
# No obstacle, distance: 1037 mm
# No obstacle, distance: 867 mm
# No obstacle, distance: 867 mm
# No obstacle, distance: 867 mm
# No obstacle, distance: 850 mm
# No obstacle, distance: 833 mm
# No obstacle, distance: 816 mm
# No obstacle, distance: 799 mm
# No obstacle, distance: 799 mm
# No obstacle, distance: 782 mm
# No obstacle, distance: 833 mm
# Obstacle is at medium distance, distance: 204 mm
# Obstacle is very close, distance: 102 mm
# No obstacle, distance: 527 mm
# No obstacle, distance: 782 mm
# No obstacle, distance: 544 mm
# Obstacle is at medium distance, distance: 219 mm
# Obstacle is very close, distance: 102 mm
# No obstacle, distance: 561 mm
# No obstacle, distance: 510 mm
# Obstacle is at medium distance, distance: 425 mm
# Obstacle is very close, distance: 68 mm
# Obstacle is at medium distance, distance: 391 mm
# Obstacle is very close, distance: 68 mm
# Obstacle is very close, distance: 68 mm
# Obstacle is very close, distance: 153 mm
# No obstacle, distance: 697 mm
# No obstacle, distance: 629 mm
# No obstacle, distance: 544 mm
# No obstacle, distance: 544 mm
# No obstacle, distance: 544 mm
# Obstacle is very close, distance: 153 mm
# Obstacle is very close, distance: 153 mm
# Obstacle is very close, distance: 153 mm
# No obstacle, distance: 561 mm
# Obstacle is very close, distance: 170 mm
# No obstacle, distance: 680 mm
# No obstacle, distance: 731 mm
# No obstacle, distance: 731 mm
# No obstacle, distance: 714 mm
# No obstacle, distance: 731 mm
# No obstacle, distance: 697 mm
# No obstacle, distance: 663 mm
# Obstacle is very close, distance: 170 mm
# Obstacle is very close, distance: 153 mm
# Obstacle is very close, distance: 187 mm
# No obstacle, distance: 714 mm
# No obstacle, distance: 731 mm
# No obstacle, distance: 714 mm
# No obstacle, distance: 714 mm
# No obstacle, distance: 714 mm
# No obstacle, distance: 714 mm
# No obstacle, distance: 697 mm
# No obstacle, distance: 714 mm
# No obstacle, distance: 646 mm
# No obstacle, distance: 629 mm
# No obstacle, distance: 561 mm
# Obstacle is very close, distance: 153 mm
# Obstacle is very close, distance: 153 mm
# No obstacle, distance: 612 mm
# Obstacle is very close, distance: 153 mm
# Obstacle is very close, distance: 187 mm
# No obstacle, distance: 629 mm
# Obstacle is at medium distance, distance: 221 mm
# Obstacle is very close, distance: 187 mm
# Obstacle is very close, distance: 187 mm
# Obstacle is at medium distance, distance: 204 mm
# Obstacle is at medium distance, distance: 238 mm
# Obstacle is at medium distance, distance: 255 mm
# Obstacle is at medium distance, distance: 238 mm
# Obstacle is at medium distance, distance: 255 mm
# No obstacle, distance: 493 mm
# No obstacle, distance: 510 mm
# No obstacle, distance: 510 mm
# No obstacle, distance: 527 mm
# No obstacle, distance: 527 mm
# Ending

# %%
# 清理资源 Cleaning up resources
del bot
